# %% [markdown]
# ## A sniplet generating data simulating a high throughput expression analysis experiment

# %%
import numpy as np
import numpy.random as npr
import pandas as pd

def generate_expression_data(n_analytes=100, n_samples=2, n_replicates=3, p_regulated=0.2, mean_offset=3.0, var=0.2, diff_var=2.0):
    # Here we follow a convension, The first sample is the reference i.e. have all label 1
    labels = npr.binomial(1, p_regulated, (n_analytes,n_samples-1))
    template = np.hstack((np.zeros((n_analytes,1)),labels))
    
    # We expand the template labels into several replicates
    regulated = np.repeat(template,n_replicates, axis=1)
    
    # If the reading is regulated, offset it with a random offset sampled from the normal distribution 
    offset = regulated*npr.normal(0,diff_var,(n_analytes,1))
    
    # Model a differentexpression level for the different analytes
    expr_level = np.ones((n_analytes,n_samples*n_replicates))*npr.normal(mean_offset,mean_offset,(n_analytes,1))
    
    # add noice for each measurement
    expression = npr.normal(offset+expr_level,var,(n_analytes,n_replicates*n_samples))
    expression = 2**expression
    
    analyte_names = ["a"+str(i+1) for i in range(n_analytes)]
    sample_names = ["s"+str(i+1)+'_'+str(j+1) for i in range(n_samples) for j in range(n_replicates)]
    
    # Create a dataframe for expression values
    expr_df = pd.DataFrame(expression,columns=sample_names,index=analyte_names)
    expr_df.loc["Sample",:] = [i+1 for i in range(n_samples) for j in range(n_replicates)]
    
    # Create a dataframe with answers if the reading was modeled as differential or not
    label_df = pd.DataFrame(template,columns=[i+1 for i in range(n_samples)],index=analyte_names)
                
    return expr_df,label_df

# %%
dat = generate_expression_data(n_analytes=10000)
data_labels = dat[1][:]
data = dat[0][:-1]

# %%
import scipy.stats as scistat

pval_plur = []

# Generate p-values through t-test
for i in range(0, data.shape[0]):
    pval_plur.append(scistat.ttest_ind(data.iloc[i, :3], data.iloc[i, 3:])[1])

# %% [markdown]
# # Generate q-values

# %%
def qvals(pval_plur):

    """ Takes a list of p-values and generates q-values as an np.array """
    
    # Number of p-values
    m = len(pval_plur)

    # Create an array with tuples of index and value from pval_plur
    pval_plur = [[x, y] for x, y in sorted(enumerate(pval_plur))]
    pval_plur = np.array(pval_plur)

    # Sort after p-values, smallest to largest
    pval_plur = pval_plur[np.argsort(pval_plur[:, 1])]

    # Set our lambda and t
    lambd = 0.5
    t = 0.05

    # Count how many p-values are greater than our lambda
    i = 0
    for j in range(0, len(pval_plur)):
        if pval_plur[j][1] > lambd:
            i += 1
        else:
            next
    lambda_count = i

    # Calculate our Pi_0 and Q_P_i(m)
    pi_zero = lambda_count/(m*(1-lambd))
    qpim = pi_zero*pval_plur[-1][1]

    #qpii = [[1000, qpim]]
    qpii = []

    # generate q-values iterating over the ordered p-value-indexes from pval_plur
    for i in reversed(range(1, len(pval_plur)+1)):
        if i == len(pval_plur):
            qval = min(((pi_zero*pval_plur[i-1][1]*m)/i), pi_zero*pval_plur[i-2][1])
        else:
            qval = min(((pi_zero*pval_plur[i-1][1]*m)/i), pi_zero*pval_plur[i][1])

        qpii.append([pval_plur[i-1][0], qval])

    qpii = np.array(qpii)
    #qvals = np.array(qpii[::-1])

    #qvals = qpii[np.argsort(qpii[:,0])]

    return qpii

# %%
a = qvals(pval_plur)
a
# Out:
# array([[  9.17100000e+03,   8.07318127e-01],
#        [  4.61000000e+03,   8.07376265e-01],
#        [  7.87400000e+03,   8.07318127e-01],
#        ...,
#        [  4.62100000e+03,   1.08851430e-07],
#        [  5.47700000e+03,   8.02140357e-08],
#        [  9.44000000e+03,   5.03987187e-08]])

# %% [markdown]
# ### Make a dataframe of q-values and the null statistic

# %%
#put them together before cumsum

q = qvals(pval_plur)
q = q[np.argsort(q[:,0])]



df = pd.DataFrame({'q':q[:,1], 'labs':data_labels.iloc[:,1]})

df = df.sort_values(by='q')

null = np.cumsum(1-df.iloc[:,0])/range(1, len(df.iloc[:,0])+1)
df['null'] = null


del df['labs']

# df.loc[df.iloc[:,0]>2000].index
# df.loc[df['q']==2278].index

# %% [markdown]
# #### 5. Plot the (simulated) number of differential expression genes as a function of q-value threshold.

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

plt.hist(df.iloc[:,0]);

# %%
df;

# %% [markdown]
# ###### 6. Plot the difference between q-values and the actual fraction of null statistics (using the labels from the generator).

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
from pylab import *

# True positives in data
(data_labels.iloc[:,1] == 1).describe()[3]

# plt.plot(q_of_pi_zero, cumsum(1-data_labels.iloc[:,1])/range(1, len(data_labels)+1))
plt.plot(df.iloc[:,0], df.iloc[:,1]);
plt.xlabel("q(p_i)", size=15)
plt.ylabel("null", size=15)
plt.title("Q-values vs fraction of null statistics", size=17);

# %%
import pandas as pd
df = pd.read_excel("MSB-12-901-s009.xlsx",skiprows=list(range(6))+list(range(15,18)),parse_cols=[0]+list(range(3,318)),header=0,index_col=0)

# %%
df
# Out:
#                                                         _02_1      _02_2  \
# Participant_Timepoint
# Weight                                              84.800000  71.500000
# BMI                                                 31.400000  26.200000
# Cholesterol                                          5.200000   4.300000
# LDL                                                  3.200000   2.600000
# HDL                                                  1.800000   1.300000
# Triglyceride                                         0.600000   0.800000
# HOMA-IR                                              1.478400   2.764178
# Leptin                                              17.000000   5.900000
# A0A024R6I7;A0A0G2JRN3                                9.384310   9.410237
# A0A075B6H9                                           8.918735   8.984415
# A0A075B6I0                                           9.090399   9.055054
# A0A075B6I1                                           8.431114   8.309657
# A0A075B6I2                                           7.966115   8.009408
# A0A075B6I5;P01702;P06316                             8.982913   9.063225
# A0A075B6I9                                           9.140631   9.235167
# A0A075B6J3                                                NaN        NaN
# A0A075B6J4                                           9.184549   9.280607
# A0A075B6J7                                           9.117453   9.205791
# A0A075B6J8                                           7.833708   7.746976
# A0A075B6J9                                           8.426316   8.457664
# A0A075B6K4                                           8.474281   8.508435
# A0A075B6K5                                           8.359781   8.602800
# A0A075B6K6                                                NaN        NaN
# A0A075B6K9;P0CG05                                   10.712700  10.756280
# A0A075B6L0;P0CG06                                    7.462718   7.686547
# A0A075B6L1;A0M8Q6                                    8.937349   9.244448
# A0A075B6N7                                                NaN        NaN
# A0A075B6Q5                                           7.237544   7.655624
# A0A0C4DH68;A0A075B6R9                                8.631643   8.616465
# A0A087X0P6;A0A075B6S2;A0A0A0MRZ7                     9.180915   9.276966
# ...                                                       ...        ...
# Q96P70                                                    NaN        NaN
# Q96PD5;Q96PD5-2                                      8.849033   8.809818
# Q96S96                                                    NaN        NaN
# Q99627;Q99627-2                                           NaN        NaN
# Q99784;Q99784-5;Q99784-3;Q99784-2;F5GZQ2;F8W870...   6.552573   7.035670
# Q99832;Q99832-4;Q99832-3;Q99832-2                         NaN        NaN
# Q9BTY2                                                    NaN        NaN
# Q9BUN1                                               6.960894   6.772842
# Q9BWP8;Q9BWP8-9;Q9BWP8-8;Q9BWP8-7;Q9BWP8-6;Q9BW...   7.164531   7.248115
# Q9BXR6                                               7.762446   7.656749
# Q9H257;Q9H257-3;Q9H257-2                             8.106599   8.037067
# Q9H4B7                                                    NaN   7.314183
# Q9H773                                                    NaN        NaN
# Q9HBR0                                                    NaN        NaN
# Q9NPH3-5;Q9NPH3-2;H7C3W4;C9J9W1;Q9NPH3-3             7.009536   7.027186
# Q9NPY3                                                    NaN        NaN
# Q9NR30;Q9NR30-2                                           NaN        NaN
# Q9NZP8;H0YFL7                                        8.612336   8.761115
# Q9UBB4;Q9UBB4-2                                           NaN        NaN
# Q9UGM5;Q9UGM5-2;E9PG08                               8.341002   8.260925
# Q9UHG3;F8W8W4;Q9UHG3-2;C9JM55;C9K055;C9JGT6               NaN        NaN
# Q9ULC0;Q9ULC0-2;Q9ULC0-3                                  NaN        NaN
# Q9ULI3;Q9ULI3-2                                      7.293912   7.227296
# Q9UNN8                                                    NaN        NaN
# Q9UNW1;Q9UNW1-3;Q9UNW1-4;Q9UNW1-2                         NaN        NaN
# Q9Y3T9                                                    NaN        NaN
# Q9Y490                                               7.143077   6.622804
# Q9Y5C1                                                    NaN        NaN
# Q9Y5S9;Q9Y5S9-2                                           NaN        NaN
# Q9Y5Y7                                                    NaN        NaN
#
#                                                         _02_3      _02_4  \
# Participant_Timepoint
# Weight                                              71.000000  70.000000
# BMI                                                       NaN        NaN
# Cholesterol                                               NaN        NaN
# LDL                                                       NaN        NaN
# HDL                                                       NaN        NaN
# Triglyceride                                              NaN        NaN
# HOMA-IR                                                   NaN        NaN
# Leptin                                              17.000000   9.270000
# A0A024R6I7;A0A0G2JRN3                                9.408777   9.482436
# A0A075B6H9                                           8.960561   8.932846
# A0A075B6I0                                           8.997038   9.052515
# A0A075B6I1                                           8.135550   8.288545
# A0A075B6I2                                           7.850430   7.928467
# A0A075B6I5;P01702;P06316                             9.053120   9.067480
# A0A075B6I9                                           9.361082   9.207253
# A0A075B6J3                                                NaN        NaN
# A0A075B6J4                                           9.195454   9.285729
# A0A075B6J7                                           9.300961   9.234211
# A0A075B6J8                                           7.668525   7.705359
# A0A075B6J9                                           8.401323   8.620039
# A0A075B6K4                                           8.371778   8.539050
# A0A075B6K5                                           8.476782   8.512589
# A0A075B6K6                                                NaN        NaN
# A0A075B6K9;P0CG05                                   10.683010  10.716630
# A0A075B6L0;P0CG06                                    7.415441   7.713137
# A0A075B6L1;A0M8Q6                                    9.255111   9.005308
# A0A075B6N7                                                NaN        NaN
# A0A075B6Q5                                           6.736157        NaN
# A0A0C4DH68;A0A075B6R9                                8.509512   8.701700
# A0A087X0P6;A0A075B6S2;A0A0A0MRZ7                     8.855369   9.343763
# ...                                                       ...        ...
# Q96P70                                                    NaN        NaN
# Q96PD5;Q96PD5-2                                      8.879448   8.764071
# Q96S96                                                    NaN        NaN
# Q99627;Q99627-2                                           NaN        NaN
# Q99784;Q99784-5;Q99784-3;Q99784-2;F5GZQ2;F8W870...   7.174583   6.526816
# Q99832;Q99832-4;Q99832-3;Q99832-2                         NaN        NaN
# Q9BTY2                                                    NaN        NaN
# Q9BUN1                                               6.765549   7.150480
# Q9BWP8;Q9BWP8-9;Q9BWP8-8;Q9BWP8-7;Q9BWP8-6;Q9BW...   7.233411   7.289321
# Q9BXR6                                               7.796193   7.865028
# Q9H257;Q9H257-3;Q9H257-2                             8.087126   7.952432
# Q9H4B7                                                    NaN   7.091702
# Q9H773                                                    NaN        NaN
# Q9HBR0                                                    NaN        NaN
# Q9NPH3-5;Q9NPH3-2;H7C3W4;C9J9W1;Q9NPH3-3                  NaN   6.866269
# Q9NPY3                                                    NaN        NaN
# Q9NR30;Q9NR30-2                                           NaN        NaN
# Q9NZP8;H0YFL7                                        8.658688   8.696676
# Q9UBB4;Q9UBB4-2                                           NaN        NaN
# Q9UGM5;Q9UGM5-2;E9PG08                               8.336040   8.286116
# Q9UHG3;F8W8W4;Q9UHG3-2;C9JM55;C9K055;C9JGT6          7.472713        NaN
# Q9ULC0;Q9ULC0-2;Q9ULC0-3                                  NaN        NaN
# Q9ULI3;Q9ULI3-2                                      7.082905   7.154370
# Q9UNN8                                                    NaN   7.042575
# Q9UNW1;Q9UNW1-3;Q9UNW1-4;Q9UNW1-2                         NaN        NaN
# Q9Y3T9                                                    NaN        NaN
# Q9Y490                                               7.864974   7.689605
# Q9Y5C1                                                    NaN   6.578229
# Q9Y5S9;Q9Y5S9-2                                           NaN        NaN
# Q9Y5Y7                                                    NaN        NaN
#
#                                                         _02_5      _02_6  \
# Participant_Timepoint
# Weight                                              71.500000  73.200000
# BMI                                                       NaN        NaN
# Cholesterol                                               NaN        NaN
# LDL                                                       NaN        NaN
# HDL                                                       NaN        NaN
# Triglyceride                                              NaN        NaN
# HOMA-IR                                                   NaN        NaN
# Leptin                                              13.400000   8.000000
# A0A024R6I7;A0A0G2JRN3                                9.483630   9.472084
# A0A075B6H9                                           8.888815   8.682663
# A0A075B6I0                                           9.073662   9.203547
# A0A075B6I1                                           8.206241   8.232878
# A0A075B6I2                                           7.854250   7.915487
# A0A075B6I5;P01702;P06316                             8.981130   8.283506
# A0A075B6I9                                           9.399657   9.467562
# A0A075B6J3                                                NaN        NaN
# A0A075B6J4                                           9.236535   9.260201
# A0A075B6J7                                           9.175428   9.286918
# A0A075B6J8                                           7.651985   7.616674
# A0A075B6J9                                           8.450325   8.450697
# A0A075B6K4                                           8.326900   8.403896
# A0A075B6K5                                           8.404433   8.624571
# A0A075B6K6                                                NaN        NaN
# A0A075B6K9;P0CG05                                   10.753250  10.730050
# A0A075B6L0;P0CG06                                    7.855840   7.481338
# A0A075B6L1;A0M8Q6                                    9.124116   9.064999
# A0A075B6N7                                                NaN        NaN
# A0A075B6Q5                                           7.509256        NaN
# A0A0C4DH68;A0A075B6R9                                8.607641   8.694465
# A0A087X0P6;A0A075B6S2;A0A0A0MRZ7                     9.249541   9.248356
# ...                                                       ...        ...
# Q96P70                                                    NaN        NaN
# Q96PD5;Q96PD5-2                                      8.807997   8.905298
# Q96S96                                                    NaN        NaN
# Q99627;Q99627-2                                           NaN        NaN
# Q99784;Q99784-5;Q99784-3;Q99784-2;F5GZQ2;F8W870...   7.146974        NaN
# Q99832;Q99832-4;Q99832-3;Q99832-2                         NaN        NaN
# Q9BTY2                                                    NaN        NaN
# Q9BUN1                                               7.081743   7.359019
# Q9BWP8;Q9BWP8-9;Q9BWP8-8;Q9BWP8-7;Q9BWP8-6;Q9BW...   7.128632   7.084830
# Q9BXR6                                               7.563089   7.829005
# Q9H257;Q9H257-3;Q9H257-2                             8.515357   8.096152
# Q9H4B7                                               7.545270   8.407544
# Q9H773                                                    NaN        NaN
# Q9HBR0                                                    NaN        NaN
# Q9NPH3-5;Q9NPH3-2;H7C3W4;C9J9W1;Q9NPH3-3                  NaN        NaN
# Q9NPY3                                               6.300465   6.304792
# Q9NR30;Q9NR30-2                                           NaN        NaN
# Q9NZP8;H0YFL7                                        8.559258   8.715259
# Q9UBB4;Q9UBB4-2                                           NaN        NaN
# Q9UGM5;Q9UGM5-2;E9PG08                               8.420394   8.329438
# Q9UHG3;F8W8W4;Q9UHG3-2;C9JM55;C9K055;C9JGT6               NaN        NaN
# Q9ULC0;Q9ULC0-2;Q9ULC0-3                                  NaN        NaN
# Q9ULI3;Q9ULI3-2                                      7.089658        NaN
# Q9UNN8                                                    NaN   7.298656
# Q9UNW1;Q9UNW1-3;Q9UNW1-4;Q9UNW1-2                         NaN        NaN
# Q9Y3T9                                                    NaN        NaN
# Q9Y490                                               7.382499   7.143828
# Q9Y5C1                                                    NaN   6.270679
# Q9Y5S9;Q9Y5S9-2                                           NaN        NaN
# Q9Y5Y7                                                    NaN   6.919726
#
#                                                         _02_7      _03_1  \
# Participant_Timepoint
# Weight                                              72.000000  97.650000
# BMI                                                 26.630000  36.000000
# Cholesterol                                          4.700000   4.700000
# LDL                                                  2.900000   3.000000
# HDL                                                  1.500000   1.200000
# Triglyceride                                         0.600000   1.200000
# HOMA-IR                                              1.600000   5.758644
# Leptin                                               8.750000  23.700000
# A0A024R6I7;A0A0G2JRN3                                9.370497   9.580927
# A0A075B6H9                                           9.100348   8.534421
# A0A075B6I0                                           8.943748   8.422598
# A0A075B6I1                                           8.552498   8.054749
# A0A075B6I2                                           7.681106   8.035768
# A0A075B6I5;P01702;P06316                             8.654648   8.584774
# A0A075B6I9                                           9.438647   9.003380
# A0A075B6J3                                                NaN        NaN
# A0A075B6J4                                           9.624893   8.971605
# A0A075B6J7                                           9.504244   9.148548
# A0A075B6J8                                           7.759089   7.475627
# A0A075B6J9                                           8.240089   8.044088
# A0A075B6K4                                           8.398888   8.164433
# A0A075B6K5                                           8.689875   8.458530
# A0A075B6K6                                                NaN        NaN
# A0A075B6K9;P0CG05                                   10.812640  10.577460
# A0A075B6L0;P0CG06                                    7.776861   7.608205
# A0A075B6L1;A0M8Q6                                    9.319906   9.288252
# A0A075B6N7                                                NaN        NaN
# A0A075B6Q5                                                NaN   7.351061
# A0A0C4DH68;A0A075B6R9                                8.541574   8.509700
# A0A087X0P6;A0A075B6S2;A0A0A0MRZ7                     9.269369   8.629532
# ...                                                       ...        ...
# Q96P70                                                    NaN        NaN
# Q96PD5;Q96PD5-2                                      8.840371   8.997387
# Q96S96                                                    NaN        NaN
# Q99627;Q99627-2                                           NaN        NaN
# Q99784;Q99784-5;Q99784-3;Q99784-2;F5GZQ2;F8W870...        NaN        NaN
# Q99832;Q99832-4;Q99832-3;Q99832-2                         NaN        NaN
# Q9BTY2                                                    NaN        NaN
# Q9BUN1                                                    NaN        NaN
# Q9BWP8;Q9BWP8-9;Q9BWP8-8;Q9BWP8-7;Q9BWP8-6;Q9BW...   7.307727   6.947615
# Q9BXR6                                               7.819471   7.838108
# Q9H257;Q9H257-3;Q9H257-2                             8.218877   8.180241
# Q9H4B7                                               8.101818        NaN
# Q9H773                                                    NaN        NaN
# Q9HBR0                                                    NaN        NaN
# Q9NPH3-5;Q9NPH3-2;H7C3W4;C9J9W1;Q9NPH3-3             7.092966   6.948882
# Q9NPY3                                                    NaN        NaN
# Q9NR30;Q9NR30-2                                           NaN        NaN
# Q9NZP8;H0YFL7                                        8.774851   8.590954
# Q9UBB4;Q9UBB4-2                                           NaN        NaN
# Q9UGM5;Q9UGM5-2;E9PG08                               8.614338   8.265532
# Q9UHG3;F8W8W4;Q9UHG3-2;C9JM55;C9K055;C9JGT6          7.463356   7.467700
# Q9ULC0;Q9ULC0-2;Q9ULC0-3                                  NaN        NaN
# Q9ULI3;Q9ULI3-2                                      7.158634        NaN
# Q9UNN8                                               7.093246   7.236411
# Q9UNW1;Q9UNW1-3;Q9UNW1-4;Q9UNW1-2                         NaN        NaN
# Q9Y3T9                                                    NaN        NaN
# Q9Y490                                               7.833855   7.237112
# Q9Y5C1                                                    NaN        NaN
# Q9Y5S9;Q9Y5S9-2                                           NaN        NaN
# Q9Y5Y7                                                    NaN   7.190500
#
#                                                         _03_2      _03_3  \
# Participant_Timepoint
# Weight                                              85.800000  82.600000
# BMI                                                 30.000000        NaN
# Cholesterol                                          3.400000        NaN
# LDL                                                  2.000000        NaN
# HDL                                                  0.900000        NaN
# Triglyceride                                         0.700000        NaN
# HOMA-IR                                              4.599444        NaN
# Leptin                                               6.690000   5.520000
# A0A024R6I7;A0A0G2JRN3                                9.670189   9.689987
# A0A075B6H9                                           8.627316   8.763565
# A0A075B6I0                                           8.377160   8.434143
# A0A075B6I1                                           8.046690   8.136787
# A0A075B6I2                                           8.083920   8.258530
# A0A075B6I5;P01702;P06316                             8.527686   8.672384
# A0A075B6I9                                           9.186728   9.012941
# A0A075B6J3                                                NaN        NaN
# A0A075B6J4                                           9.068478   9.028275
# A0A075B6J7                                           9.046856   9.008374
# A0A075B6J8                                           7.504277   7.576146
# A0A075B6J9                                           8.051065   7.945882
# A0A075B6K4                                           8.219689   8.102877
# A0A075B6K5                                           8.497374   8.467222
# A0A075B6K6                                                NaN        NaN
# A0A075B6K9;P0CG05                                   10.569800  10.537710
# A0A075B6L0;P0CG06                                    7.590413   7.305615
# A0A075B6L1;A0M8Q6                                    9.224585   9.069253
# A0A075B6N7                                                NaN        NaN
# A0A075B6Q5                                           7.295774        NaN
# A0A0C4DH68;A0A075B6R9                                8.577116   8.372868
# A0A087X0P6;A0A075B6S2;A0A0A0MRZ7                     8.356771   8.243534
# ...                                                       ...        ...
# Q96P70                                                    NaN        NaN
# Q96PD5;Q96PD5-2                                      9.012474   8.908987
# Q96S96                                                    NaN        NaN
# Q99627;Q99627-2                                           NaN        NaN
# Q99784;Q99784-5;Q99784-3;Q99784-2;F5GZQ2;F8W870...   7.248709        NaN
# Q99832;Q99832-4;Q99832-3;Q99832-2                         NaN        NaN
# Q9BTY2                                                    NaN        NaN
# Q9BUN1                                                    NaN   6.882667
# Q9BWP8;Q9BWP8-9;Q9BWP8-8;Q9BWP8-7;Q9BWP8-6;Q9BW...        NaN        NaN
# Q9BXR6                                               7.713440   7.680299
# Q9H257;Q9H257-3;Q9H257-2                             7.973386   7.743706
# Q9H4B7                                                    NaN   7.552315
# Q9H773                                                    NaN        NaN
# Q9HBR0                                                    NaN        NaN
# Q9NPH3-5;Q9NPH3-2;H7C3W4;C9J9W1;Q9NPH3-3             7.454174   7.162206
# Q9NPY3                                               6.424980        NaN
# Q9NR30;Q9NR30-2                                           NaN        NaN
# Q9NZP8;H0YFL7                                        8.709624   8.655770
# Q9UBB4;Q9UBB4-2                                           NaN        NaN
# Q9UGM5;Q9UGM5-2;E9PG08                               8.268017   8.209917
# Q9UHG3;F8W8W4;Q9UHG3-2;C9JM55;C9K055;C9JGT6          7.238999   7.287802
# Q9ULC0;Q9ULC0-2;Q9ULC0-3                                  NaN        NaN
# Q9ULI3;Q9ULI3-2                                      6.892268        NaN
# Q9UNN8                                                    NaN        NaN
# Q9UNW1;Q9UNW1-3;Q9UNW1-4;Q9UNW1-2                         NaN        NaN
# Q9Y3T9                                                    NaN        NaN
# Q9Y490                                               6.198439   8.615816
# Q9Y5C1                                                    NaN        NaN
# Q9Y5S9;Q9Y5S9-2                                           NaN        NaN
# Q9Y5Y7                                               7.441899   7.313586
#
#                                                       ...          _57_2  \
# Participant_Timepoint                                 ...
# Weight                                                ...      92.000000
# BMI                                                   ...      28.000000
# Cholesterol                                           ...       4.000000
# LDL                                                   ...       2.500000
# HDL                                                   ...       0.900000
# Triglyceride                                          ...       1.500000
# HOMA-IR                                               ...       5.003333
# Leptin                                                ...       3.740000
# A0A024R6I7;A0A0G2JRN3                                 ...       8.955029
# A0A075B6H9                                            ...       9.108068
# A0A075B6I0                                            ...       8.985046
# A0A075B6I1                                            ...       8.595130
# A0A075B6I2                                            ...       7.894744
# A0A075B6I5;P01702;P06316                              ...       9.049809
# A0A075B6I9                                            ...       9.167032
# A0A075B6J3                                            ...            NaN
# A0A075B6J4                                            ...       9.258528
# A0A075B6J7                                            ...       8.980463
# A0A075B6J8                                            ...       7.481370
# A0A075B6J9                                            ...       8.819489
# A0A075B6K4                                            ...       8.285265
# A0A075B6K5                                            ...       8.081665
# A0A075B6K6                                            ...            NaN
# A0A075B6K9;P0CG05                                     ...      10.692710
# A0A075B6L0;P0CG06                                     ...       7.881536
# A0A075B6L1;A0M8Q6                                     ...       8.756216
# A0A075B6N7                                            ...            NaN
# A0A075B6Q5                                            ...       7.595441
# A0A0C4DH68;A0A075B6R9                                 ...       9.188911
# A0A087X0P6;A0A075B6S2;A0A0A0MRZ7                      ...       8.176819
# ...                                                   ...            ...
# Q96P70                                                ...       5.512204
# Q96PD5;Q96PD5-2                                       ...       8.795308
# Q96S96                                                ...            NaN
# Q99627;Q99627-2                                       ...            NaN
# Q99784;Q99784-5;Q99784-3;Q99784-2;F5GZQ2;F8W870...    ...       6.710659
# Q99832;Q99832-4;Q99832-3;Q99832-2                     ...            NaN
# Q9BTY2                                                ...            NaN
# Q9BUN1                                                ...            NaN
# Q9BWP8;Q9BWP8-9;Q9BWP8-8;Q9BWP8-7;Q9BWP8-6;Q9BW...    ...       7.392679
# Q9BXR6                                                ...       7.527166
# Q9H257;Q9H257-3;Q9H257-2                              ...       7.801966
# Q9H4B7                                                ...       8.341613
# Q9H773                                                ...            NaN
# Q9HBR0                                                ...            NaN
# Q9NPH3-5;Q9NPH3-2;H7C3W4;C9J9W1;Q9NPH3-3              ...       7.155279
# Q9NPY3                                                ...            NaN
# Q9NR30;Q9NR30-2                                       ...            NaN
# Q9NZP8;H0YFL7                                         ...       8.564880
# Q9UBB4;Q9UBB4-2                                       ...            NaN
# Q9UGM5;Q9UGM5-2;E9PG08                                ...       8.265124
# Q9UHG3;F8W8W4;Q9UHG3-2;C9JM55;C9K055;C9JGT6           ...            NaN
# Q9ULC0;Q9ULC0-2;Q9ULC0-3                              ...            NaN
# Q9ULI3;Q9ULI3-2                                       ...       7.399206
# Q9UNN8                                                ...       7.240948
# Q9UNW1;Q9UNW1-3;Q9UNW1-4;Q9UNW1-2                     ...            NaN
# Q9Y3T9                                                ...            NaN
# Q9Y490                                                ...       7.222991
# Q9Y5C1                                                ...            NaN
# Q9Y5S9;Q9Y5S9-2                                       ...            NaN
# Q9Y5Y7                                                ...            NaN
#
#                                                         _57_3      _57_4  \
# Participant_Timepoint
# Weight                                              92.000000  93.000000
# BMI                                                       NaN        NaN
# Cholesterol                                               NaN        NaN
# LDL                                                       NaN        NaN
# HDL                                                       NaN        NaN
# Triglyceride                                              NaN        NaN
# HOMA-IR                                                   NaN        NaN
# Leptin                                               4.530000   9.000000
# A0A024R6I7;A0A0G2JRN3                                8.506492   8.485269
# A0A075B6H9                                           9.125790   9.154156
# A0A075B6I0                                           8.916378   8.926514
# A0A075B6I1                                           8.681826   8.663883
# A0A075B6I2                                           7.704866   7.552169
# A0A075B6I5;P01702;P06316                             9.207473   9.127357
# A0A075B6I9                                           9.160809   9.088869
# A0A075B6J3                                                NaN        NaN
# A0A075B6J4                                           9.262970   9.165575
# A0A075B6J7                                           8.859962   8.884272
# A0A075B6J8                                           7.423737   7.429413
# A0A075B6J9                                           8.941716   8.930130
# A0A075B6K4                                           8.327322   8.281235
# A0A075B6K5                                           8.214748   8.218192
# A0A075B6K6                                                NaN        NaN
# A0A075B6K9;P0CG05                                   10.692030  10.702510
# A0A075B6L0;P0CG06                                    7.679700   7.869730
# A0A075B6L1;A0M8Q6                                    8.677969   8.863465
# A0A075B6N7                                                NaN        NaN
# A0A075B6Q5                                                NaN        NaN
# A0A0C4DH68;A0A075B6R9                                9.077568   9.067139
# A0A087X0P6;A0A075B6S2;A0A0A0MRZ7                     8.730988   8.571901
# ...                                                       ...        ...
# Q96P70                                                    NaN        NaN
# Q96PD5;Q96PD5-2                                      8.788473   8.772820
# Q96S96                                                    NaN        NaN
# Q99627;Q99627-2                                           NaN        NaN
# Q99784;Q99784-5;Q99784-3;Q99784-2;F5GZQ2;F8W870...        NaN        NaN
# Q99832;Q99832-4;Q99832-3;Q99832-2                    7.864446        NaN
# Q9BTY2                                                    NaN        NaN
# Q9BUN1                                                    NaN        NaN
# Q9BWP8;Q9BWP8-9;Q9BWP8-8;Q9BWP8-7;Q9BWP8-6;Q9BW...        NaN   7.068705
# Q9BXR6                                               7.617514   7.608408
# Q9H257;Q9H257-3;Q9H257-2                             7.810544   7.718383
# Q9H4B7                                               8.314962   7.060956
# Q9H773                                               6.247507        NaN
# Q9HBR0                                                    NaN        NaN
# Q9NPH3-5;Q9NPH3-2;H7C3W4;C9J9W1;Q9NPH3-3                  NaN   6.778130
# Q9NPY3                                                    NaN        NaN
# Q9NR30;Q9NR30-2                                      6.516139        NaN
# Q9NZP8;H0YFL7                                        8.610678   8.576737
# Q9UBB4;Q9UBB4-2                                           NaN        NaN
# Q9UGM5;Q9UGM5-2;E9PG08                               8.391386   8.297846
# Q9UHG3;F8W8W4;Q9UHG3-2;C9JM55;C9K055;C9JGT6               NaN        NaN
# Q9ULC0;Q9ULC0-2;Q9ULC0-3                                  NaN        NaN
# Q9ULI3;Q9ULI3-2                                      7.066624   7.643394
# Q9UNN8                                               6.701006   6.632407
# Q9UNW1;Q9UNW1-3;Q9UNW1-4;Q9UNW1-2                         NaN        NaN
# Q9Y3T9                                               6.109038        NaN
# Q9Y490                                               7.285566   6.805925
# Q9Y5C1                                                    NaN        NaN
# Q9Y5S9;Q9Y5S9-2                                           NaN        NaN
# Q9Y5Y7                                               7.022820   7.352568
#
#                                                         _57_5      _57_6  \
# Participant_Timepoint
# Weight                                              92.400000  94.500000
# BMI                                                       NaN        NaN
# Cholesterol                                               NaN        NaN
# LDL                                                       NaN        NaN
# HDL                                                       NaN        NaN
# Triglyceride                                              NaN        NaN
# HOMA-IR                                                   NaN        NaN
# Leptin                                               6.770000   6.010000
# A0A024R6I7;A0A0G2JRN3                                8.572326   8.459483
# A0A075B6H9                                           8.903898   8.931898
# A0A075B6I0                                           9.013231   8.908621
# A0A075B6I1                                           8.702065   8.702471
# A0A075B6I2                                           7.719073   7.612115
# A0A075B6I5;P01702;P06316                             9.082893   9.250347
# A0A075B6I9                                           9.146871   9.176959
# A0A075B6J3                                                NaN        NaN
# A0A075B6J4                                           9.206120   9.323686
# A0A075B6J7                                           8.999228   9.142145
# A0A075B6J8                                           7.384479   7.455445
# A0A075B6J9                                           8.846687   8.871415
# A0A075B6K4                                           8.352144   8.272074
# A0A075B6K5                                           8.161384   8.198909
# A0A075B6K6                                           6.946559   6.800353
# A0A075B6K9;P0CG05                                   10.621590  10.664680
# A0A075B6L0;P0CG06                                    7.662248   7.116663
# A0A075B6L1;A0M8Q6                                    8.864260   8.286367
# A0A075B6N7                                                NaN        NaN
# A0A075B6Q5                                                NaN   7.663692
# A0A0C4DH68;A0A075B6R9                                8.915935   9.182686
# A0A087X0P6;A0A075B6S2;A0A0A0MRZ7                     8.796160   8.460958
# ...                                                       ...        ...
# Q96P70                                                    NaN        NaN
# Q96PD5;Q96PD5-2                                      8.748135   8.781448
# Q96S96                                                    NaN        NaN
# Q99627;Q99627-2                                           NaN        NaN
# Q99784;Q99784-5;Q99784-3;Q99784-2;F5GZQ2;F8W870...        NaN        NaN
# Q99832;Q99832-4;Q99832-3;Q99832-2                         NaN        NaN
# Q9BTY2                                                    NaN        NaN
# Q9BUN1                                                    NaN        NaN
# Q9BWP8;Q9BWP8-9;Q9BWP8-8;Q9BWP8-7;Q9BWP8-6;Q9BW...   7.118133   7.019025
# Q9BXR6                                               7.545567   7.745594
# Q9H257;Q9H257-3;Q9H257-2                             8.003986   7.987702
# Q9H4B7                                               7.088698   6.870305
# Q9H773                                                    NaN        NaN
# Q9HBR0                                                    NaN        NaN
# Q9NPH3-5;Q9NPH3-2;H7C3W4;C9J9W1;Q9NPH3-3                  NaN   7.263328
# Q9NPY3                                                    NaN        NaN
# Q9NR30;Q9NR30-2                                           NaN        NaN
# Q9NZP8;H0YFL7                                        8.693481   8.700500
# Q9UBB4;Q9UBB4-2                                           NaN        NaN
# Q9UGM5;Q9UGM5-2;E9PG08                               8.286141   8.364684
# Q9UHG3;F8W8W4;Q9UHG3-2;C9JM55;C9K055;C9JGT6               NaN        NaN
# Q9ULC0;Q9ULC0-2;Q9ULC0-3                                  NaN        NaN
# Q9ULI3;Q9ULI3-2                                      6.962975   7.214433
# Q9UNN8                                                    NaN        NaN
# Q9UNW1;Q9UNW1-3;Q9UNW1-4;Q9UNW1-2                    6.600722        NaN
# Q9Y3T9                                                    NaN        NaN
# Q9Y490                                               7.358260   7.142552
# Q9Y5C1                                                    NaN        NaN
# Q9Y5S9;Q9Y5S9-2                                           NaN        NaN
# Q9Y5Y7                                               6.754260        NaN
#
#                                                         _57_7       _58_1  \
# Participant_Timepoint
# Weight                                              96.800000  104.800000
# BMI                                                 29.160000   31.800000
# Cholesterol                                          4.300000    4.000000
# LDL                                                  2.400000    2.100000
# HDL                                                  0.900000    1.500000
# Triglyceride                                         2.250000    0.800000
# HOMA-IR                                             11.948000    8.255556
# Leptin                                               6.910000   33.000000
# A0A024R6I7;A0A0G2JRN3                                8.208898    9.607462
# A0A075B6H9                                           9.024222    8.740736
# A0A075B6I0                                           8.869701    8.796613
# A0A075B6I1                                           8.613501    8.241886
# A0A075B6I2                                           7.661106    8.335114
# A0A075B6I5;P01702;P06316                             8.893884    8.845554
# A0A075B6I9                                           9.069520    9.277361
# A0A075B6J3                                                NaN         NaN
# A0A075B6J4                                           9.261523    9.373257
# A0A075B6J7                                           9.093334    8.927192
# A0A075B6J8                                           7.466541    7.428038
# A0A075B6J9                                           8.756549    8.420912
# A0A075B6K4                                           8.190941    8.154812
# A0A075B6K5                                           8.181439    8.285238
# A0A075B6K6                                           6.988434    7.178537
# A0A075B6K9;P0CG05                                   10.675660   10.557000
# A0A075B6L0;P0CG06                                    7.647870    7.357630
# A0A075B6L1;A0M8Q6                                    8.842981    9.149151
# A0A075B6N7                                                NaN         NaN
# A0A075B6Q5                                           7.841872         NaN
# A0A0C4DH68;A0A075B6R9                                9.023369    8.922554
# A0A087X0P6;A0A075B6S2;A0A0A0MRZ7                     8.869918    8.529348
# ...                                                       ...         ...
# Q96P70                                                    NaN         NaN
# Q96PD5;Q96PD5-2                                      8.724062    8.754555
# Q96S96                                                    NaN         NaN
# Q99627;Q99627-2                                           NaN         NaN
# Q99784;Q99784-5;Q99784-3;Q99784-2;F5GZQ2;F8W870...        NaN    7.084791
# Q99832;Q99832-4;Q99832-3;Q99832-2                         NaN         NaN
# Q9BTY2                                                    NaN         NaN
# Q9BUN1                                                    NaN         NaN
# Q9BWP8;Q9BWP8-9;Q9BWP8-8;Q9BWP8-7;Q9BWP8-6;Q9BW...   7.000824         NaN
# Q9BXR6                                               7.618895    7.909433
# Q9H257;Q9H257-3;Q9H257-2                             7.942132    7.685070
# Q9H4B7                                                    NaN    7.721746
# Q9H773                                                    NaN         NaN
# Q9HBR0                                                    NaN         NaN
# Q9NPH3-5;Q9NPH3-2;H7C3W4;C9J9W1;Q9NPH3-3                  NaN    7.471380
# Q9NPY3                                                    NaN         NaN
# Q9NR30;Q9NR30-2                                           NaN         NaN
# Q9NZP8;H0YFL7                                        8.772017    8.554385
# Q9UBB4;Q9UBB4-2                                           NaN         NaN
# Q9UGM5;Q9UGM5-2;E9PG08                               8.362083    8.370773
# Q9UHG3;F8W8W4;Q9UHG3-2;C9JM55;C9K055;C9JGT6               NaN    6.966428
# Q9ULC0;Q9ULC0-2;Q9ULC0-3                                  NaN         NaN
# Q9ULI3;Q9ULI3-2                                           NaN    7.269926
# Q9UNN8                                               6.880213    7.608612
# Q9UNW1;Q9UNW1-3;Q9UNW1-4;Q9UNW1-2                    6.562198         NaN
# Q9Y3T9                                                    NaN         NaN
# Q9Y490                                               8.135752    8.971952
# Q9Y5C1                                                    NaN         NaN
# Q9Y5S9;Q9Y5S9-2                                           NaN         NaN
# Q9Y5Y7                                                    NaN    7.219488
#
#                                                         _58_2      _58_3  \
# Participant_Timepoint
# Weight                                              94.100000  95.000000
# BMI                                                 27.400000        NaN
# Cholesterol                                          2.800000        NaN
# LDL                                                  1.200000        NaN
# HDL                                                  1.300000        NaN
# Triglyceride                                         0.700000        NaN
# HOMA-IR                                              4.586667        NaN
# Leptin                                              16.300000  28.900000
# A0A024R6I7;A0A0G2JRN3                                9.732481   9.760927
# A0A075B6H9                                           8.659849   8.556024
# A0A075B6I0                                           8.745747   8.731321
# A0A075B6I1                                           8.195170   8.134278
# A0A075B6I2                                           8.194396   8.121626
# A0A075B6I5;P01702;P06316                             7.490731   8.898078
# A0A075B6I9                                           9.157724   8.995350
# A0A075B6J3                                                NaN        NaN
# A0A075B6J4                                           9.416043   9.127040
# A0A075B6J7                                           8.916307   8.916975
# A0A075B6J8                                           7.415391   7.319148
# A0A075B6J9                                           8.442490   8.492626
# A0A075B6K4                                           8.292898   8.188305
# A0A075B6K5                                           8.295521   8.165968
# A0A075B6K6                                           7.442824   7.236260
# A0A075B6K9;P0CG05                                   10.566210  10.550160
# A0A075B6L0;P0CG06                                    7.706078   7.744136
# A0A075B6L1;A0M8Q6                                    9.340913   9.096981
# A0A075B6N7                                                NaN        NaN
# A0A075B6Q5                                                NaN        NaN
# A0A0C4DH68;A0A075B6R9                                8.775057   8.822855
# A0A087X0P6;A0A075B6S2;A0A0A0MRZ7                     8.818655   8.676773
# ...                                                       ...        ...
# Q96P70                                               5.655906        NaN
# Q96PD5;Q96PD5-2                                      8.711893   8.705317
# Q96S96                                                    NaN        NaN
# Q99627;Q99627-2                                           NaN        NaN
# Q99784;Q99784-5;Q99784-3;Q99784-2;F5GZQ2;F8W870...        NaN        NaN
# Q99832;Q99832-4;Q99832-3;Q99832-2                         NaN        NaN
# Q9BTY2                                                    NaN        NaN
# Q9BUN1                                               7.137987        NaN
# Q9BWP8;Q9BWP8-9;Q9BWP8-8;Q9BWP8-7;Q9BWP8-6;Q9BW...   7.336381        NaN
# Q9BXR6                                               7.844365   7.938119
# Q9H257;Q9H257-3;Q9H257-2                                  NaN        NaN
# Q9H4B7                                               7.970787   8.478696
# Q9H773                                                    NaN        NaN
# Q9HBR0                                                    NaN        NaN
# Q9NPH3-5;Q9NPH3-2;H7C3W4;C9J9W1;Q9NPH3-3             7.382255   7.288361
# Q9NPY3                                                    NaN        NaN
# Q9NR30;Q9NR30-2                                           NaN        NaN
# Q9NZP8;H0YFL7                                        8.645475   8.617694
# Q9UBB4;Q9UBB4-2                                           NaN        NaN
# Q9UGM5;Q9UGM5-2;E9PG08                               8.662407   8.664991
# Q9UHG3;F8W8W4;Q9UHG3-2;C9JM55;C9K055;C9JGT6          7.456951   7.388789
# Q9ULC0;Q9ULC0-2;Q9ULC0-3                                  NaN        NaN
# Q9ULI3;Q9ULI3-2                                      7.208184   7.081851
# Q9UNN8                                               7.228708        NaN
# Q9UNW1;Q9UNW1-3;Q9UNW1-4;Q9UNW1-2                         NaN        NaN
# Q9Y3T9                                                    NaN        NaN
# Q9Y490                                               6.567420   6.815177
# Q9Y5C1                                                    NaN        NaN
# Q9Y5S9;Q9Y5S9-2                                           NaN        NaN
# Q9Y5Y7                                               7.095936   7.267922
#
#                                                         _58_4
# Participant_Timepoint
# Weight                                              96.000000
# BMI                                                       NaN
# Cholesterol                                               NaN
# LDL                                                       NaN
# HDL                                                       NaN
# Triglyceride                                              NaN
# HOMA-IR                                                   NaN
# Leptin                                              28.300000
# A0A024R6I7;A0A0G2JRN3                                9.797781
# A0A075B6H9                                           8.850599
# A0A075B6I0                                           8.851284
# A0A075B6I1                                           8.135195
# A0A075B6I2                                           8.198227
# A0A075B6I5;P01702;P06316                             8.977078
# A0A075B6I9                                           9.274189
# A0A075B6J3                                                NaN
# A0A075B6J4                                           9.312214
# A0A075B6J7                                           8.979843
# A0A075B6J8                                           7.167978
# A0A075B6J9                                           8.301502
# A0A075B6K4                                           8.206132
# A0A075B6K5                                           8.209351
# A0A075B6K6                                           7.334394
# A0A075B6K9;P0CG05                                   10.543230
# A0A075B6L0;P0CG06                                    7.379426
# A0A075B6L1;A0M8Q6                                    9.157213
# A0A075B6N7                                                NaN
# A0A075B6Q5                                           7.211014
# A0A0C4DH68;A0A075B6R9                                8.889308
# A0A087X0P6;A0A075B6S2;A0A0A0MRZ7                     8.660489
# ...                                                       ...
# Q96P70                                                    NaN
# Q96PD5;Q96PD5-2                                      8.595817
# Q96S96                                                    NaN
# Q99627;Q99627-2                                           NaN
# Q99784;Q99784-5;Q99784-3;Q99784-2;F5GZQ2;F8W870...   6.905127
# Q99832;Q99832-4;Q99832-3;Q99832-2                         NaN
# Q9BTY2                                                    NaN
# Q9BUN1                                                    NaN
# Q9BWP8;Q9BWP8-9;Q9BWP8-8;Q9BWP8-7;Q9BWP8-6;Q9BW...   6.919972
# Q9BXR6                                               8.045639
# Q9H257;Q9H257-3;Q9H257-2                                  NaN
# Q9H4B7                                               8.186335
# Q9H773                                                    NaN
# Q9HBR0                                                    NaN
# Q9NPH3-5;Q9NPH3-2;H7C3W4;C9J9W1;Q9NPH3-3             7.337399
# Q9NPY3                                                    NaN
# Q9NR30;Q9NR30-2                                           NaN
# Q9NZP8;H0YFL7                                        8.675070
# Q9UBB4;Q9UBB4-2                                           NaN
# Q9UGM5;Q9UGM5-2;E9PG08                               8.816686
# Q9UHG3;F8W8W4;Q9UHG3-2;C9JM55;C9K055;C9JGT6          7.692565
# Q9ULC0;Q9ULC0-2;Q9ULC0-3                                  NaN
# Q9ULI3;Q9ULI3-2                                           NaN
# Q9UNN8                                                    NaN
# Q9UNW1;Q9UNW1-3;Q9UNW1-4;Q9UNW1-2                         NaN
# Q9Y3T9                                                    NaN
# Q9Y490                                               6.904021
# Q9Y5C1                                                    NaN
# Q9Y5S9;Q9Y5S9-2                                           NaN
# Q9Y5Y7                                               7.085580
#
# [745 rows x 315 columns]
